# %% [markdown]
# <a href="https://colab.research.google.com/github/pravallika-naraharisetti/MachineLearning/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load dataset (Heart Disease Dataset from UCI)

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"

columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df = pd.read_csv(url, names=columns, na_values="?")
# 1⃣Quick Data Overview
print("Dataset Shape:", df.shape)
print("\nFirst 5 Rows:\n", df.head())
# 2⃣Handle Missing Values
print("\nMissing Values:\n", df.isnull().sum())
df.dropna(inplace=True)
# 3⃣Class Distribution (Check for Imbalance)
plt.figure(figsize=(5, 3))
sns.countplot(x=df['target'], palette="viridis")
plt.title("Class Distribution")
plt.xlabel("Target Class (0: No Disease, 1-4: Disease)")
plt.ylabel("Count")
plt.show()
# 4⃣Feature Correlations (Top 5 correlated with target)
correlation = df.corr()['target'].abs().sort_values(ascending=False)
print("\nTop Correlated Features with Target:\n", correlation.head(5))
# 5⃣Boxplot of Select Features (Outlier Detection)
selected_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
plt.figure(figsize=(8, 4))
sns.boxplot(data=df[selected_features])
plt.xticks(rotation=90)
plt.title("Boxplot of Selected Features")
plt.show()
# Out:
# Dataset Shape: (303, 14)
#
# First 5 Rows:
#      age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       2
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0
#
# Missing Values:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64
# <ipython-input-2-3217a4a6b2c9>:19: FutureWarning:
# ...
